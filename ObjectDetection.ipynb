# %%
import torch
import cv2
import matplotlib.pyplot as plt

model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

img_path = 'photo.jpg'
img = cv2.imread(img_path)

results = model(img)

results.print()
results.show()
# Out:
# Using cache found in C:\Users\LENOVO/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-10-16 Python-3.12.5 torch-2.3.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# image 1/1: 1080x1920 4 persons
# Speed: 1.0ms pre-process, 100.1ms inference, 1.0ms NMS per image at shape (1, 3, 384, 640)
# <PIL.Image.Image image mode=RGB size=1920x1080>
